# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp,sales, color="red", edgecolors="black")

# Set the upper and lower limits of our y axis
plt.xlim(min(temp)-1,max(temp)+1)

# Set the upper and lower limits of our x axis
plt.ylim(min(sales)-5,max(sales)+5)

# Create a title, x label, and y label for our chart
plt.xlabel("Tempurature (Celsius)")
plt.ylabel("Sales (Dollars)")
plt.title("Ice Cream Sales v Temperature")

# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cell again.
# Out:
# Text(0.5, 1.0, 'Ice Cream Sales v Temperature')

# %% [markdown]
# Then
# * Create a new list called scoop_price, fill it with values, and then set it so that the size of the dots are set according to those values.  YOU are inputting your own price so everyone's chart should look different.

# %%
#Create a new list called scoop_price, fill it with values
scoop_price = [x*40 for x in range(1,len(temp)+1)]
print(scoop_price)
# Out:
# [40, 80, 120, 160, 200, 240, 280, 320, 360, 400, 440, 480]

# %%
# new plt with scoop price implemented
plt.scatter(temp,sales,s = scoop_price, color="red", edgecolors="black")

# Set the upper and lower limits of our y axis
plt.xlim(min(temp)-1,max(temp)+1)

# Set the upper and lower limits of our x axis
plt.ylim(min(sales)-5,max(sales)+5)

# Create a title, x label, and y label for our chart
plt.xlabel("Tempurature (Celsius)")
plt.ylabel("Sales (Dollars)")
plt.title("Ice Cream Sales v Temperature")
# Out:
# Text(0.5, 1.0, 'Ice Cream Sales v Temperature')

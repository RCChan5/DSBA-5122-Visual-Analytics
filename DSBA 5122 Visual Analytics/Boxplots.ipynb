# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Example outlier plot of reaction times
times = [96,98,100,105,85,88,95,100,101,102,97,98,5]
fig1, ax1 = plt.subplots()
ax1.set_title('Reaction Times at Baseball Batting Cage')
ax1.set_ylabel('Reaction Time (ms)')
ax1.boxplot(times)
plt.show()

# %%
times.sort()
print(times)
# Out:
# [5, 85, 88, 95, 96, 97, 98, 98, 100, 100, 101, 102, 105]

# %%
# Read in the LAX temperature data
temperature_df = pd.read_csv('Resources/lax_temperature.csv')
temperatures = temperature_df['HourlyDryBulbTemperature']

fig1, ax1 = plt.subplots()
ax1.set_title('Temperatures at LAX')
ax1.set_ylabel('Temperature')
ax1.boxplot(temperatures)
plt.show()

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = temperatures.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

# %%
lower_bound = lowerq -(1.5*iqr)
print(f"Values below {lower_bound} are outliers.")
# Out:
# Values below 45.0 are outliers.

# %%
temperature_df.head()
# Out:
#        STATION                 DATE REPORT_TYPE  HourlyDryBulbTemperature
# 0  72295023174  2019-01-01T00:49:00       FM-16                        52
# 1  72295023174  2019-01-01T00:53:00       FM-15                        51
# 2  72295023174  2019-01-01T01:53:00       FM-15                        52
# 3  72295023174  2019-01-01T02:53:00       FM-15                        49
# 4  72295023174  2019-01-01T03:53:00       FM-15                        43

# %%
#Basic Boxplot
import altair as alt
alt.Chart(temperature_df).mark_boxplot().encode(
    x='REPORT_TYPE',
    y='HourlyDryBulbTemperature')
# Out:
# alt.Chart(...)

# %%
#Looks a little hard to read lets change the size
import altair as alt
alt.Chart(temperature_df).mark_boxplot().encode(
    x='REPORT_TYPE',
    y='HourlyDryBulbTemperature').properties(width=500)
# Out:
# alt.Chart(...)

# %%
#Looks a little hard to read lets change the size
import altair as alt
alt.Chart(temperature_df).mark_boxplot(size=100).encode(
    x='REPORT_TYPE',
    y='HourlyDryBulbTemperature').properties(width=500)
# Out:
# alt.Chart(...)

# %%
#We dont need to see 0 in the axis
import altair as alt
alt.Chart(temperature_df).mark_boxplot(size=100).encode(
    x='REPORT_TYPE',
    y=alt.Y('HourlyDryBulbTemperature',scale=alt.Scale(zero=False))).properties(width=500)
# Out:
# alt.Chart(...)

# %%
#Looks a little hard to read lets change the size
import altair as alt
alt.Chart(temperature_df).mark_boxplot(size=100).encode(
    x='REPORT_TYPE',
    y=alt.Y('HourlyDryBulbTemperature',scale=alt.Scale(zero=False)),
    color=alt.Color('STATION:O')).properties(width=500)
# Out:
# alt.Chart(...)

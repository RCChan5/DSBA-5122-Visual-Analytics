# %%
# Dependencies
import pandas as pd
from matplotlib import pyplot as plt
import scipy.stats as sts
import numpy as np

# Read in the LAX temperature data
temperature_df = pd.read_csv('Resources/lax_temperature.csv')
temperatures = temperature_df['HourlyDryBulbTemperature']
temperature_df.head(5)
# Out:
#        STATION                 DATE REPORT_TYPE  HourlyDryBulbTemperature
# 0  72295023174  2019-01-01T00:49:00       FM-16                        52
# 1  72295023174  2019-01-01T00:53:00       FM-15                        51
# 2  72295023174  2019-01-01T01:53:00       FM-15                        52
# 3  72295023174  2019-01-01T02:53:00       FM-15                        49
# 4  72295023174  2019-01-01T03:53:00       FM-15                        43

# %%
mean = np.mean(temperatures)
print(mean)
#f string
print(f"the mean temperature at LAX is : {mean}")
# Out:
# 57.65514310002834
# the mean temperature at LAX is : 57.65514310002834

# %%
median = np.median(temperatures)
print(median)
print(f"the mean temperature at LAX is : {median}")
# Out:
# 57.0
# the mean temperature at LAX is : 57.0

# %%
plt.hist(temperatures)
plt.xlabel("temp")
plt.ylabel("Frequency")
plt.show()

# %%
#pip install altair
import altair as alt

# %%
alt.Chart(temperature_df).mark_bar().encode(
    alt.X("HourlyDryBulbTemperature",bin = True),
    y = "count()"
)
# Out:
# alt.Chart(...)

# %%
sd = np.std(temperatures)
print(f"roughly 68% of data is between {round(mean-sd,2)} and {round(mean +sd,2)}")
# Out:
# roughly 68% of data is between 51.97 and 63.34

# %%
# Out:
#                Country  Income_Per_Capita  Population (in thousands) total  \
# 0          Afghanistan                NaN                          26088.0
# 1              Albania             6000.0                           3172.0
# 2              Algeria             5940.0                          33351.0
# 3              Andorra                NaN                             74.0
# 4               Angola             3890.0                          16557.0
# 5  Antigua and Barbuda            15130.0                             84.0
# 6            Argentina            11670.0                          39134.0
# 7              Armenia             4950.0                           3010.0
# 8            Australia            33940.0                          20530.0
# 9              Austria            36040.0                           8327.0
#
#    Population_Median_Age  Percent_Population_over_60  \
# 0                   16.0                         4.0
# ...
